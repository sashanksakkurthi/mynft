# %%
import requests

response = requests.post("http://127.0.0.1:7860/run/predict", json={
  "data": [
    5,
]}).json()

data = response["data"]

# %%
print(data[0])
# Out:
# data:image/png;base64,...
